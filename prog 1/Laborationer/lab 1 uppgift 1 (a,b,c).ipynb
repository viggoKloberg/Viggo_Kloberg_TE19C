# %%
# a
import random 
import numpy as np 
import matplotlib.pyplot as plt
x = [-1,0,1]
y = [-1,0,1]

dotCount = 1000
spread = 1
radius = 1

color = 0
hits = 0

for i in range(1,dotCount+1):
    xDot = random.uniform(-spread,spread)
    yDot = random.uniform(-spread,spread)
   
    dist = np.sqrt(xDot**2 + yDot**2)
    if dist <= radius:
        color = 'green'
        hits += 1
    else:
        color = 'red'
    plt.plot (xDot, yDot, 'o-', color=color)

hitPercent = 100 * hits/dotCount 
print(hitPercent,"% träffar")


plt.show
# Out:
# 79.4 % träffar
# <function matplotlib.pyplot.show(*args, **kw)>
