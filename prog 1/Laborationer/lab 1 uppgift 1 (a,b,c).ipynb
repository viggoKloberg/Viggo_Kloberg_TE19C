# %%
import random 
import numpy as np 
import matplotlib.pyplot as plt

dotCount = 1000
spread = 1
radius = 1

color = 0
hits = 0

for i in range(1,dotCount+1):
    xDot = random.uniform(-spread,spread)
    yDot = random.uniform(-spread,spread)
   
    dist = np.sqrt(xDot**2 + yDot**2)
    if dist <= radius:
        color = "green"
        hits += 1
    else:
        color = "red"
    plt.plot (xDot, yDot, 'o-', color=color)
    plt.axis("equal")

hitPercent = 100 * hits/dotCount 
print(hitPercent,"% träffar")

pi = 4 * hits/dotCount
print(pi)
# detta blir ca. pi, då det blir en omvänd formel för arean av en cirkel

plt.show
# Out:
# 79.2 % träffar
# 3.168
# <function matplotlib.pyplot.show(*args, **kw)>
